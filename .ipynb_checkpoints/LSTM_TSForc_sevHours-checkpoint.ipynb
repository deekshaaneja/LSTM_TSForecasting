# %% [markdown]
# ## Forecasting several hours in the future considering several hours from the past, based on LSTM Recurrent Neural Networks

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# specify the number of lag hours
n_hours_past = 10
n_hours_future = 3
n_features = 8

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# load dataset
dataset = read_csv('pollution.csv', header=0, index_col=0)
values = dataset.values
# integer encode wind direction
encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, n_hours_past, n_hours_future)
#print(reframed.shape)
#print(reframed.head())
# Out:
# (43788, 104)
#     var1(t-10)  var2(t-10)  var3(t-10)  var4(t-10)  var5(t-10)  var6(t-10)  \
# 10    0.129779    0.352941    0.245902    0.527273    0.666667    0.002290
# 11    0.148893    0.367647    0.245902    0.527273    0.666667    0.003811
# 12    0.159960    0.426471    0.229508    0.545454    0.666667    0.005332
# 13    0.182093    0.485294    0.229508    0.563637    0.666667    0.008391
# 14    0.138833    0.485294    0.229508    0.563637    0.666667    0.009912
#
#     var7(t-10)  var8(t-10)  var1(t-9)  var2(t-9)    ...      var7(t+1)  \
# 10    0.000000         0.0   0.148893   0.367647    ...            0.0
# 11    0.000000         0.0   0.159960   0.426471    ...            0.0
# 12    0.000000         0.0   0.182093   0.485294    ...            0.0
# 13    0.037037         0.0   0.138833   0.485294    ...            0.0
# 14    0.074074         0.0   0.109658   0.485294    ...            0.0
#
#     var8(t+1)  var1(t+2)  var2(t+2)  var3(t+2)  var4(t+2)  var5(t+2)  \
# 10        0.0   0.148893   0.470588   0.229508   0.636364   0.666667
# 11        0.0   0.164990   0.470588   0.229508   0.618183   0.666667
# 12        0.0   0.158954   0.455882   0.229508   0.618183   0.666667
# 13        0.0   0.154930   0.455882   0.229508   0.618183   0.666667
# 14        0.0   0.159960   0.455882   0.229508   0.636364   0.666667
#
#     var6(t+2)  var7(t+2)  var8(t+2)
# 10   0.039716        0.0        0.0
# 11   0.046586        0.0        0.0
# 12   0.053456        0.0        0.0
# 13   0.060326        0.0        0.0
# 14   0.063385        0.0        0.0
#
# [5 rows x 104 columns]

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 365 * 24
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]

# split into input and outputs
## We will take n_hours_past * n_features columns as input for the obs of 
## all features across the previous n_hours_past hours
n_obs = n_hours_past * n_features

train_X = train[:, :n_obs]
test_X = test[:, :n_obs]

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours_past, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours_past, n_features))
print(train_X.shape, test_X.shape)
# Out:
# (8760, 10, 8) (35028, 10, 8)

# %%
# Here we take n_hours_future columns of the following n_hours_future pollution values
names = list()
for i in range(0, n_hours_future):
    if i == 0:
        names += ['var1(t)']
    else:
        names += [('var1(t+%d)' % (i))]

output = reframed[names]
print(output.head())
print(output.shape)

out_values = output.values

# reshape output to be 3D [samples, timesteps]
out_values = out_values.reshape((out_values.shape[0], n_hours_future))

train_y = out_values[:n_train_hours, :]
test_y = out_values[n_train_hours:, :]

print(train_y.shape, test_y.shape)
# Out:
#      var1(t)  var1(t+1)  var1(t+2)
# 10  0.140845   0.152918   0.148893
# 11  0.152918   0.148893   0.164990
# 12  0.148893   0.164990   0.158954
# 13  0.164990   0.158954   0.154930
# 14  0.158954   0.154930   0.159960
# (43788, 3)
# (8760, 3) (35028, 3)

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(n_hours_future))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train on 8760 samples, validate on 35028 samples
# Epoch 1/50
#  - 3s - loss: 0.0543 - val_loss: 0.0598
# Epoch 2/50
#  - 2s - loss: 0.0382 - val_loss: 0.0444
# Epoch 3/50
#  - 2s - loss: 0.0337 - val_loss: 0.0357
# Epoch 4/50
#  - 2s - loss: 0.0313 - val_loss: 0.0310
# Epoch 5/50
#  - 2s - loss: 0.0297 - val_loss: 0.0303
# Epoch 6/50
#  - 2s - loss: 0.0281 - val_loss: 0.0294
# Epoch 7/50
#  - 2s - loss: 0.0270 - val_loss: 0.0284
# Epoch 8/50
#  - 2s - loss: 0.0260 - val_loss: 0.0279
# Epoch 9/50
#  - 2s - loss: 0.0252 - val_loss: 0.0275
# Epoch 10/50
#  - 2s - loss: 0.0246 - val_loss: 0.0270
# Epoch 11/50
#  - 2s - loss: 0.0239 - val_loss: 0.0268
# Epoch 12/50
#  - 2s - loss: 0.0234 - val_loss: 0.0256
# Epoch 13/50
#  - 2s - loss: 0.0229 - val_loss: 0.0248
# Epoch 14/50
#  - 2s - loss: 0.0227 - val_loss: 0.0244
# Epoch 15/50
#  - 2s - loss: 0.0224 - val_loss: 0.0241
# Epoch 16/50
#  - 2s - loss: 0.0222 - val_loss: 0.0243
# Epoch 17/50
#  - 2s - loss: 0.0221 - val_loss: 0.0242
# Epoch 18/50
#  - 2s - loss: 0.0219 - val_loss: 0.0236
# Epoch 19/50
#  - 2s - loss: 0.0218 - val_loss: 0.0237
# Epoch 20/50
#  - 2s - loss: 0.0217 - val_loss: 0.0235
# Epoch 21/50
#  - 2s - loss: 0.0215 - val_loss: 0.0235
# Epoch 22/50
#  - 2s - loss: 0.0214 - val_loss: 0.0234
# Epoch 23/50
#  - 2s - loss: 0.0214 - val_loss: 0.0236
# Epoch 24/50
#  - 2s - loss: 0.0213 - val_loss: 0.0235
# Epoch 25/50
#  - 2s - loss: 0.0213 - val_loss: 0.0233
# Epoch 26/50
#  - 2s - loss: 0.0213 - val_loss: 0.0233
# Epoch 27/50
#  - 2s - loss: 0.0213 - val_loss: 0.0231
# Epoch 28/50
#  - 2s - loss: 0.0212 - val_loss: 0.0230
# Epoch 29/50
#  - 2s - loss: 0.0212 - val_loss: 0.0228
# Epoch 30/50
#  - 2s - loss: 0.0212 - val_loss: 0.0227
# Epoch 31/50
#  - 2s - loss: 0.0212 - val_loss: 0.0227
# Epoch 32/50
#  - 2s - loss: 0.0212 - val_loss: 0.0228
# Epoch 33/50
#  - 2s - loss: 0.0211 - val_loss: 0.0228
# Epoch 34/50
#  - 2s - loss: 0.0211 - val_loss: 0.0229
# Epoch 35/50
#  - 2s - loss: 0.0211 - val_loss: 0.0227
# Epoch 36/50
#  - 2s - loss: 0.0211 - val_loss: 0.0227
# Epoch 37/50
#  - 2s - loss: 0.0211 - val_loss: 0.0228
# Epoch 38/50
#  - 2s - loss: 0.0210 - val_loss: 0.0228
# Epoch 39/50
#  - 2s - loss: 0.0211 - val_loss: 0.0229
# Epoch 40/50
#  - 2s - loss: 0.0210 - val_loss: 0.0227
# Epoch 41/50
#  - 2s - loss: 0.0210 - val_loss: 0.0228
# Epoch 42/50
#  - 2s - loss: 0.0210 - val_loss: 0.0228
# Epoch 43/50
#  - 2s - loss: 0.0210 - val_loss: 0.0228
# Epoch 44/50
#  - 2s - loss: 0.0209 - val_loss: 0.0227
# Epoch 45/50
#  - 2s - loss: 0.0210 - val_loss: 0.0228
# Epoch 46/50
#  - 2s - loss: 0.0209 - val_loss: 0.0228
# Epoch 47/50
#  - 2s - loss: 0.0209 - val_loss: 0.0228
# Epoch 48/50
#  - 2s - loss: 0.0209 - val_loss: 0.0230
# Epoch 49/50
#  - 2s - loss: 0.0209 - val_loss: 0.0230
# Epoch 50/50
#  - 2s - loss: 0.0208 - val_loss: 0.0229

# %%
# make a prediction
yhat = model.predict(test_X)

# %%
test_X_reshaped = test_X.reshape((test_X.shape[0], n_hours_past*n_features))

for i in range(0, n_hours_future):
    yhat_i = yhat[:,i]
    yhat_i = yhat_i.reshape((yhat_i.shape[0],1))
    
    test_y_i = test_y[:,i]
    test_y_i = test_y_i.reshape((test_y_i.shape[0],1))
    
    # invert normalization of forecast values
    inv_yhat_i = concatenate((yhat_i, test_X_reshaped[:, -7:]), axis=1)
    inv_yhat_i = scaler.inverse_transform(inv_yhat_i)
    inv_yhat_i = inv_yhat_i[:,0]
    
    # invert normalization of actual values
    inv_y_i = concatenate((test_y_i, test_X_reshaped[:, -7:]), axis=1)
    inv_y_i = scaler.inverse_transform(inv_y_i)
    inv_y_i = inv_y_i[:,0]
    
    # calculate RMSE
    rmse_i = sqrt(mean_squared_error(inv_y_i, inv_yhat_i))
    print('Test RMSE %d hour ahead: %.3f' % (i+1,rmse_i))
# Out:
# Test RMSE 0 hour ahead: 26.362
# Test RMSE 1 hour ahead: 37.907
# Test RMSE 2 hour ahead: 51.331
